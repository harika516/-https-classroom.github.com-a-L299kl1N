# %%
# Read the Dataset and replace the dashes with zeros

# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("Laliga.csv")

# %%
dataset.head()
# Out:
#   Unnamed: 0       Unnamed: 1 Unnamed: 2 Unnamed: 3   Unnamed: 4 Unnamed: 5  \
# 0        Pos             Team    Seasons     Points  GamesPlayed   GamesWon
# 1          1      Real Madrid         86       4385         2762       1647
# 2          2        Barcelona         86       4262         2762       1581
# 3          3  Atletico Madrid         80       3442         2614       1241
# 4          4         Valencia         82       3386         2664       1187
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8    Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# 0  GamesDrawn  GamesLost   GoalsFor  GoalsAgainst    Champion   Runner-up
# 1         552        563       5947          3140          33          23
# 2         573        608       5900          3114          25          25
# 3         598        775       4534          3309          10           8
# 4         616        861       4398          3469           6           6
#
# ...

# %%
dataset.replace(to_replace='-',value=0,inplace=True)

# %%
dataset
# Out:
#    Unnamed: 0           Unnamed: 1 Unnamed: 2 Unnamed: 3   Unnamed: 4  \
# 0         Pos                 Team    Seasons     Points  GamesPlayed
# 1           1          Real Madrid         86       4385         2762
# 2           2            Barcelona         86       4262         2762
# 3           3      Atletico Madrid         80       3442         2614
# 4           4             Valencia         82       3386         2664
# 5           5      Athletic Bilbao         86       3368         2762
# 6           6              Sevilla         73       2819         2408
# 7           7             Espanyol         82       2792         2626
# 8           8        Real Sociedad         70       2573         2302
# 9           9             Zaragoza         58       2109         1986
# 10         10           Real Betis         51       1884         1728
# 11         11  Deportivo La Coruna         45       1814         1530
# ...

# %%
#Print all the teams which have started between 1930-1980

# %%
dataset.rename(columns=dataset.iloc[0],inplace=True)

# %%
dataset
# Out:
#     Pos                 Team  Seasons  Points  GamesPlayed  GamesWon  \
# 0   Pos                 Team  Seasons  Points  GamesPlayed  GamesWon
# 1     1          Real Madrid       86    4385         2762      1647
# 2     2            Barcelona       86    4262         2762      1581
# 3     3      Atletico Madrid       80    3442         2614      1241
# 4     4             Valencia       82    3386         2664      1187
# 5     5      Athletic Bilbao       86    3368         2762      1209
# 6     6              Sevilla       73    2819         2408       990
# 7     7             Espanyol       82    2792         2626       948
# 8     8        Real Sociedad       70    2573         2302       864
# 9     9             Zaragoza       58    2109         1986       698
# 10   10           Real Betis       51    1884         1728       606
# 11   11  Deportivo La Coruna       45    1814         1530       563
# 12   12           Celta Vigo       51    1789         1698       586
# ...

# %%
dataset
# Out:
#     Pos                 Team  Seasons  Points  GamesPlayed  GamesWon  \
# 0   Pos                 Team  Seasons  Points  GamesPlayed  GamesWon
# 1     1          Real Madrid       86    4385         2762      1647
# 2     2            Barcelona       86    4262         2762      1581
# 3     3      Atletico Madrid       80    3442         2614      1241
# 4     4             Valencia       82    3386         2664      1187
# 5     5      Athletic Bilbao       86    3368         2762      1209
# 6     6              Sevilla       73    2819         2408       990
# 7     7             Espanyol       82    2792         2626       948
# 8     8        Real Sociedad       70    2573         2302       864
# 9     9             Zaragoza       58    2109         1986       698
# 10   10           Real Betis       51    1884         1728       606
# 11   11  Deportivo La Coruna       45    1814         1530       563
# 12   12           Celta Vigo       51    1789         1698       586
# ...

# %%
dataset.drop(index=0,inplace=True)

# %%
newds=dataset['Debut'].str.split("-",n=1,expand=True)

# %%
dataset["starting yr"]=newds[0]

# %%
dataset["end yr"]=newds[1]

# %%
dataset
# Out:
#    Pos                 Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 1    1          Real Madrid      86   4385        2762     1647        552
# 2    2            Barcelona      86   4262        2762     1581        573
# 3    3      Atletico Madrid      80   3442        2614     1241        598
# 4    4             Valencia      82   3386        2664     1187        616
# 5    5      Athletic Bilbao      86   3368        2762     1209        633
# 6    6              Sevilla      73   2819        2408      990        531
# 7    7             Espanyol      82   2792        2626      948        608
# 8    8        Real Sociedad      70   2573        2302      864        577
# 9    9             Zaragoza      58   2109        1986      698        522
# 10  10           Real Betis      51   1884        1728      606        440
# 11  11  Deportivo La Coruna      45   1814        1530      563        392
# ...

# %%
dataset.drop(columns =["Debut"], inplace = True)

# %%
dataset
# Out:
#    Pos                 Team Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 1    1          Real Madrid      86   4385        2762     1647        552
# 2    2            Barcelona      86   4262        2762     1581        573
# 3    3      Atletico Madrid      80   3442        2614     1241        598
# 4    4             Valencia      82   3386        2664     1187        616
# 5    5      Athletic Bilbao      86   3368        2762     1209        633
# 6    6              Sevilla      73   2819        2408      990        531
# 7    7             Espanyol      82   2792        2626      948        608
# 8    8        Real Sociedad      70   2573        2302      864        577
# 9    9             Zaragoza      58   2109        1986      698        522
# 10  10           Real Betis      51   1884        1728      606        440
# 11  11  Deportivo La Coruna      45   1814        1530      563        392
# ...

# %%
dataset.dtypes # the datatype of starting yr is object
# Out:
# Pos              object
# Team             object
# Seasons          object
# Points           object
# GamesPlayed      object
# GamesWon         object
# GamesDrawn       object
# GamesLost        object
# GoalsFor         object
# GoalsAgainst     object
# Champion         object
# Runner-up        object
# Third            object
# Fourth           object
# Fifth            object
# Sixth            object
# T                object
# Since/LastApp    object
# BestPosition     object
# starting yr       int64
# end yr           object
# dtype: object

# %%
dataset['starting yr'] = dataset['starting yr'].apply(pd.to_numeric) # changing the datatype of 'starting yr' column
print(dataset.dtypes)
# Out:
# Pos              object
# Team             object
# Seasons          object
# Points            int64
# GamesPlayed      object
# GamesWon         object
# GamesDrawn       object
# GamesLost        object
# GoalsFor         object
# GoalsAgainst     object
# Champion         object
# Runner-up        object
# Third            object
# Fourth           object
# Fifth            object
# Sixth            object
# T                object
# Since/LastApp    object
# BestPosition     object
# starting yr       int64
# end yr           object
# dtype: object

# %%
dataset['Points'] = dataset['Points'].apply(pd.to_numeric)

# %%
dataset.dtypes
# Out:
# Pos              object
# Team             object
# Seasons          object
# Points            int64
# GamesPlayed      object
# GamesWon         object
# GamesDrawn       object
# GamesLost        object
# GoalsFor         object
# GoalsAgainst     object
# Champion         object
# Runner-up        object
# Third            object
# Fourth           object
# Fifth            object
# Sixth            object
# T                object
# Since/LastApp    object
# BestPosition     object
# starting yr       int64
# end yr           object
# dtype: object

# %%
df=dataset[['Team','starting yr']]

# %%
df.loc[(df['starting yr'] >= 1930) & (df['starting yr'] <= 1980)]
# Out:
#                    Team  starting yr
# 4              Valencia         1931
# 6               Sevilla         1934
# 9              Zaragoza         1939
# 10           Real Betis         1932
# 11  Deportivo La Coruna         1941
# 12           Celta Vigo         1939
# 13           Valladolid         1948
# 15       Sporting Gijon         1944
# 16              Osasuna         1935
# 17               Malaga         1949
# 18               Oviedo         1933
# 19             Mallorca         1960
# 20           Las Palmas         1951
# 22              Granada         1941
# 23       Rayo Vallecano         1977
# 24                Elche         1959
# 26             Hercules         1935
# 27             Tenerife         1961
# 28               Murcia         1940
# 29               Alaves         1930
# 30              Levante         1963
# 31            Salamanca         1974
# 32             Sabadell         1943
# 33                Cadiz         1977
# ...

# %%
#print aii the teams which came Top 5 in teerms of points

# %%
df1=dataset.nlargest(5,['Points'],keep='first')
df1['Team']
# Out:
# 1        Real Madrid
# 2          Barcelona
# 3    Atletico Madrid
# 4           Valencia
# 5    Athletic Bilbao
# Name: Team, dtype: object

# %%
#Write a function with name “Goal_diff_count” which should return all the teams with their Goal Differences. Using the same function, find the team which has maximum and minimum goal difference. (5 points)
#Goal_diff_count = GoalsFor - GoalsAgainst

# %%
def Goal_diff_count(x,y):
    print("Goal defference is\t\n",x-y)

# %%
dataset['GoalsFor']=dataset['GoalsFor'].apply(pd.to_numeric)

# %%
dataset['GoalsAgainst']=dataset['GoalsAgainst'].apply(pd.to_numeric)

# %%
a=dataset['GoalsFor']
b=dataset['GoalsAgainst']
Goal_diff_count(a,b)
# Out:
# Goal defference is
#  1     2807
# 2     2786
# 3     1225
# 4      929
# 5      931
# 6      307
# 7     -280
# 8       -2
# 9     -164
# 10    -333
# 11    -136
# 12    -346
# 13    -413
# 14    -525
# 15    -399
# 16    -334
# 17    -342
# 18    -309
# 19    -189
# 20    -399
# 21     103
# 22    -338
# 23    -328
# 24    -272
# 25    -113
# 26    -334
# 27    -125
# 28    -385
# 29    -165
# 30    -202
#       ...
# 32    -228
# 33    -269
# 34    -198
# 35    -169
# 36     -90
# 37    -122
# 38    -145
# 39     -42
# 40     -94
# 41     -94
# 42     -56
# 43     -98
# 44     -28
# 45     -81
# 46     -38
# 47    -114
# 48     -55
# 49     -45
# 50    -107
# 51     -62
# 52     -31
# 53     -45
# 54     -34
# 55    -112
# 56     -19
# 57     -28
# 58     -20
# 59     -34
# 60     -31
# 61       0
# Length: 61, dtype: int64

# %%
#Create a new column with name “Winning Percent” and append it to the data set (5 points)
#Percentage of Winning = (GamesWon / GamesPlayed)*100

#If there are any numerical error, replace it with 0%

#Print the top 5 teams which has the highest Winning percentage

# %%
dataset['GamesPlayed']=dataset['GamesPlayed'].apply(pd.to_numeric)
dataset['GamesWon']=dataset['GamesWon'].apply(pd.to_numeric)

# %%
dataset['Winning Percent']=dataset['GamesWon']/dataset['GamesPlayed']*100

# %%
dataset.fillna(value=0)
# Out:
#    Pos                 Team Seasons  Points  GamesPlayed  GamesWon GamesDrawn  \
# 1    1          Real Madrid      86    4385         2762      1647        552
# 2    2            Barcelona      86    4262         2762      1581        573
# 3    3      Atletico Madrid      80    3442         2614      1241        598
# 4    4             Valencia      82    3386         2664      1187        616
# 5    5      Athletic Bilbao      86    3368         2762      1209        633
# 6    6              Sevilla      73    2819         2408       990        531
# 7    7             Espanyol      82    2792         2626       948        608
# 8    8        Real Sociedad      70    2573         2302       864        577
# 9    9             Zaragoza      58    2109         1986       698        522
# 10  10           Real Betis      51    1884         1728       606        440
# 11  11  Deportivo La Coruna      45    1814         1530       563        392
# ...

# %%
df2=dataset.nlargest(5,['Winning Percent'],keep='first')
df2['Team']
# Out:
# 1        Real Madrid
# 2          Barcelona
# 3    Atletico Madrid
# 4           Valencia
# 5    Athletic Bilbao
# Name: Team, dtype: object

# %%
#Group teams based on their “Best position” and print the sum of their points for all positions (5 points)
#Eg: Best Position                Points

 #       1                              25000

  #2                              7000

# %%
dataset.columns
# Out:
# Index(['Pos', 'Team', 'Seasons', 'Points', 'GamesPlayed', 'GamesWon',
#        'GamesDrawn', 'GamesLost', 'GoalsFor', 'GoalsAgainst', 'Champion',
#        'Runner-up', 'Third', 'Fourth', 'Fifth', 'Sixth', 'T', 'Since/LastApp',
#        'BestPosition', 'starting yr', 'end yr', 'Winning Percent'],
#       dtype='object')

# %%
dataset['Points']=dataset['Points'].apply(pd.to_numeric)
dataset['BestPosition']=dataset['BestPosition'].apply(pd.to_numeric)

# %%
df3=dataset[['Points','BestPosition']]

# %%
df3.sort_values("BestPosition",ascending='True')#I am not able to understand  that "Why the 10th position comes after first position"?
# Out:
#     Points BestPosition
# 1     4385            1
# 2     4262            1
# 3     3442            1
# 4     3386            1
# 5     3368            1
# 6     2819            1
# 8     2573            1
# 10    1884            1
# 11    1814            1
# 44     132           10
# 53      52           10
# 39     190           10
# 50      76           10
# 28     445           11
# 33     343           12
# 41     168           12
# 51      71           14
# 60      14           15
# 58      22           16
# 55      40           16
# 59      19           16
# 48      83           17
# 56      35           17
# 43     148           17
# 49      81           19
# 9     2109            2
# 14    1416            2
# 21     970            2
# 20    1020            2
# 15    1389            2
# ..     ...          ...
# 45     107            3
# 19    1148            3
# 18    1174            3
# 7     2792            3
# 12    1789            4
# 32     353            4
# ...
